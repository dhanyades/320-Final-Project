# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanyades/320-Final-Project/blob/main/checkpoint2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Checkpoint 2**
#
# ---

# %% [markdown]
# **Data Preprocessing**

# %%
import pandas as pd
df = pd.read_csv("sales_historical_cars.csv")
df
# Out:
#          region    category           parameter  mode powertrain  year  \
# 0     Australia  Historical            EV sales  Cars        BEV  2011
# 1     Australia  Historical      EV stock share  Cars         EV  2011
# 2     Australia  Historical      EV sales share  Cars         EV  2011
# 3     Australia  Historical            EV stock  Cars        BEV  2011
# 4     Australia  Historical            EV stock  Cars        BEV  2012
# ...         ...         ...                 ...   ...        ...   ...
# 3793      World  Historical            EV stock  Cars        BEV  2023
# 3794      World  Historical            EV sales  Cars        BEV  2023
# 3795      World  Historical      EV sales share  Cars         EV  2023
# 3796      World  Historical      EV stock share  Cars         EV  2023
# 3797      World  Historical  Electricity demand  Cars         EV  2023
#
#           unit         value
# 0     Vehicles  4.900000e+01
# 1      percent  3.900000e-04
# ...

# %%
df = df[df['parameter'] == 'EV sales']
df = df[df['region'] != 'World']
df = df[df['region'] != 'Rest of the world']
df.drop(columns = ['unit'], inplace = True)
df
# Out:
#          region    category parameter  mode powertrain  year      value
# 0     Australia  Historical  EV sales  Cars        BEV  2011       49.0
# 6     Australia  Historical  EV sales  Cars       PHEV  2012       80.0
# 9     Australia  Historical  EV sales  Cars        BEV  2012      170.0
# 10    Australia  Historical  EV sales  Cars        BEV  2013      190.0
# 13    Australia  Historical  EV sales  Cars       PHEV  2013      100.0
# ...         ...         ...       ...   ...        ...   ...        ...
# 3629        USA  Historical  EV sales  Cars       FCEV  2022     2700.0
# 3630        USA  Historical  EV sales  Cars        BEV  2022   800000.0
# 3635        USA  Historical  EV sales  Cars        BEV  2023  1100000.0
# 3636        USA  Historical  EV sales  Cars       FCEV  2023     3000.0
# 3641        USA  Historical  EV sales  Cars       PHEV  2023   290000.0
#
# [1273 rows x 7 columns]
